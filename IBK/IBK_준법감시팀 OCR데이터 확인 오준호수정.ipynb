# %% [markdown]
# 1. 초기 설정 및 라이브러리 임포트

# %%
# 필요한 라이브러리 임포트
import os
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
from tqdm.notebook import tqdm  # 주피터 노트북에 최적화된 진행 표시줄
import concurrent.futures  # 병렬 처리용
import logging

# 경고 메시지 설정
warnings.filterwarnings('ignore', category=pd.errors.DtypeWarning)

# 로깅 설정
logging.basicConfig(level=logging.INFO, 
                   format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# 기본 경로 설정
BASE_PATH = Path(r"C:\Users\markcloud\Desktop\오준호\IBK")

# %% [markdown]
# 2. 유틸리티 함수 정의

# %%
# 파일 인코딩 자동 감지 함수
def detect_encoding(file_path):
    """파일의 인코딩을 자동으로 감지하는 함수"""
    encodings = ['utf-8', 'euc-kr', 'cp949', 'utf-16']
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as f:
                f.read(100)  # 일부만 읽어서 테스트
                return encoding
        except UnicodeDecodeError:
            continue
    return None

# 텍스트 파일 안전하게 읽기 함수
def read_text_file_safely(file_path, default_value=""):
    """텍스트 파일을 안전하게 읽는 함수"""
    if not os.path.exists(file_path):
        return default_value
    
    encoding = detect_encoding(file_path)
    if not encoding:
        logger.warning(f"적합한 인코딩을 찾을 수 없음: {file_path}")
        return default_value
    
    try:
        with open(file_path, 'r', encoding=encoding) as f:  # 여기서 errors='replace' 매개변수가 없는지 확인
            return f.read()
    except Exception as e:
        logger.warning(f"파일 읽기 오류: {file_path} - {e}")
        return default_value

# OCR 텍스트 파일 읽기 함수 (병렬 처리에 최적화)
def read_ocr_file(args):
    """OCR 파일을 읽는 함수 (병렬 처리용)"""
    subdir, ocr_file = args
    if not ocr_file or pd.isna(ocr_file):
        return ""
    
    ocr_file_path = os.path.join(subdir, ocr_file)
    return read_text_file_safely(ocr_file_path)

# 폴더 번호에 따른 상위 폴더명 반환 함수
def get_correct_base_folder(num):
    """폴더 번호에 따른 상위 폴더명 반환 함수"""
    try:
        num = int(str(num).strip())
        if 24801 <= num <= 28103:
            return "ibk_24801_start_2"
        elif 28104 <= num <= 32080:
            return "ibk_28104_start_2"
        elif 32081 <= num <= 41902:
            return "ibk_32081_start_2"
        else:
            return None
    except (ValueError, TypeError):
        return None

# %% [markdown]
# 3. OCR 데이터 수집 및 처리 함수

# %%
def collect_csv_data(folder_path):
    """CSV 파일 데이터를 수집하는 함수"""
    all_csv_files = []
    folder_path = Path(folder_path)
    
    try:
        # 모든 하위 폴더 탐색
        for subdir in tqdm(list(folder_path.glob('**/')), desc="폴더 스캔 중"):
            subdir_str = str(subdir)
            csv_files = list(subdir.glob('*.csv'))
            
            if csv_files:
                # CSV 파일 처리
                for csv_file in csv_files:
                    try:
                        # 수정된 부분: errors 매개변수 제거하고 인코딩 처리 개선
                        try:
                            df = pd.read_csv(csv_file, encoding='utf-8')
                            logger.info(f"CSV 파일 읽기 성공: {csv_file} ({len(df)} 행)")
                        except UnicodeDecodeError:
                            # 다른 인코딩 시도
                            df = pd.read_csv(csv_file, encoding='cp949')
                            logger.info(f"CSV 파일 읽기 성공(cp949): {csv_file} ({len(df)} 행)")
                        
                        # 데이터프레임에 폴더 정보 추가
                        if 'folder' not in df.columns:
                            df['folder'] = subdir.name
                        
                        all_csv_files.append(df)
                    except pd.errors.EmptyDataError:
                        logger.warning(f"빈 CSV 파일: {csv_file}")
                    except Exception as e:
                        logger.error(f"CSV 처리 오류: {csv_file} - {e}")
            else:
                # 이미지 폴더 처리
                images_dir = subdir / 'images'
                if images_dir.exists():
                    image_files = [f.name for f in images_dir.glob('*') if f.is_file()]
                    if image_files:
                        temp_df = pd.DataFrame({
                            'folder': subdir.name,
                            'image': image_files,
                            'ocr_file': '',
                            'processing_time': '',
                            'char_count': '',
                            'ocr_text': ''
                        })
                        all_csv_files.append(temp_df)
        
        if not all_csv_files:
            logger.warning("수집된 CSV 파일이 없습니다!")
            return pd.DataFrame()  # 빈 데이터프레임 반환
        
        # 모든 데이터프레임 병합
        merged_df = pd.concat(all_csv_files, ignore_index=True)
        logger.info(f"총 {len(merged_df)}개 행 수집 완료")
        return merged_df
    
    except Exception as e:
        logger.error(f"CSV 데이터 수집 중 심각한 오류 발생: {e}")
        return pd.DataFrame()  # 오류 발생해도 빈 데이터프레임 반환

def add_ocr_text_parallel(df, max_workers=4):
    """병렬 처리를 통해 OCR 텍스트 내용을 추가하는 함수"""
    if len(df) == 0:
        return df
    
    if 'ocr_file' not in df.columns:
        df['ocr_text'] = ""
        return df
    
    subdirs = df.get('subdir', df['folder'].apply(lambda x: ""))
    args_list = [(subdir, ocr_file) for subdir, ocr_file in zip(subdirs, df['ocr_file'])]
    
    # 진행 상황 표시를 위한 설정
    total = len(args_list)
    logger.info(f"OCR 텍스트 {total}개 로딩 중...")
    
    # 병렬 처리
    ocr_texts = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        ocr_texts = list(tqdm(executor.map(read_ocr_file, args_list), total=total, desc="OCR 텍스트 읽기"))
    
    df['ocr_text'] = ocr_texts
    return df

# %% [markdown]
# 4. 데이터 타입 처리 및 저장 함수

# %%
def clean_and_convert_data_types(df):
    """데이터 타입을 정리하고 변환하는 함수"""
    if len(df) == 0:
        return df
    
    # folder 열을 문자열로 변환
    df['folder'] = df['folder'].astype(str)
    
    # 숫자형 열 처리
    numeric_columns = ['processing_time', 'char_count']
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col].replace('', np.nan), errors='coerce')
    
    # object 타입 열을 모두 문자열로 변환 (Parquet 저장 오류 방지)
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].fillna("").astype(str)
    
    return df

def save_to_parquet_safely(df, file_path):
    """데이터프레임을 안전하게 Parquet으로 저장하는 함수"""
    try:
        # 데이터 타입 정제
        df = clean_and_convert_data_types(df)
        
        # 저장
        df.to_parquet(file_path, engine='pyarrow', index=False)
        logger.info(f"Parquet 저장 성공: {file_path} ({len(df)} 행)")
        return True
    except Exception as e:
        logger.error(f"Parquet 저장 오류: {e}")
        
        # 대체 저장 방식 (CSV)
        try:
            csv_path = str(file_path).replace('.parquet', '_backup.csv')
            df.to_csv(csv_path, index=False)
            logger.info(f"CSV로 대체 저장 성공: {csv_path}")
        except Exception as csv_e:
            logger.error(f"CSV 저장도 실패: {csv_e}")
        
        return False

# %% [markdown]
# 5. 텍스트 통합 및 보강 함수

# %%
def process_text_files(grouped_df, base_folder_path):
    """text.txt 파일 처리를 통해 데이터를 보강하는 함수"""
    text_contents = []
    base_folder_path = Path(base_folder_path)
    
    for index, row in tqdm(grouped_df.iterrows(), total=len(grouped_df), desc="텍스트 파일 처리"):
        folder_name = row['folder']
        upper_folder = get_correct_base_folder(folder_name)
        
        if upper_folder is None:
            logger.warning(f"[스킵] 번호 범위 밖: {folder_name}")
            text_contents.append("")
            continue
        
        folder_path = base_folder_path / upper_folder / str(folder_name)
        text_file_path = folder_path / 'text.txt'
        
        # 텍스트 파일 읽기
        text_content = read_text_file_safely(text_file_path)
        text_contents.append(text_content)
    
    # 결과 반영
    grouped_df['text'] = text_contents
    return grouped_df

# %% [markdown]
# 6. 전체 워크플로우 실행 함수

# %%
def run_full_workflow(base_path, output_base_name="IBK_processed_data"):
    """전체 데이터 처리 워크플로우를 실행하는 함수"""
    try:
        # 1. CSV 데이터 수집
        logger.info("===== 1단계: CSV 데이터 수집 =====")
        merged_df = collect_csv_data(base_path)
        
        # None 체크는 필요 없지만, 빈 데이터프레임 체크는 필요
        if merged_df is None or merged_df.empty:
            logger.error("데이터 수집 실패! 처리를 중단합니다.")
            return pd.DataFrame()  # 빈 데이터프레임 반환
        
        # 2. OCR 텍스트 추가
        logger.info("===== 2단계: OCR 텍스트 추가 =====")
        merged_df = add_ocr_text_parallel(merged_df)
        
        # 3. 첫 번째 Parquet 저장
        first_parquet_path = base_path / f"{output_base_name}_step1.parquet"
        logger.info(f"===== 3단계: 첫 번째 Parquet 저장 =====")
        if not save_to_parquet_safely(merged_df, first_parquet_path):
            # 저장 실패 시 파이프라인 계속 진행
            logger.warning("첫 번째 Parquet 저장 실패했지만 계속 진행합니다.")
        
        # 4. 필요한 열만 선택
        logger.info("===== 4단계: 데이터 필터링 =====")
        filtered_df = merged_df[['folder', 'ocr_text']]
        
        # 5. 폴더별 텍스트 통합
        logger.info("===== 5단계: 폴더별 텍스트 통합 =====")
        grouped_df = (
            filtered_df
            .groupby('folder', as_index=False)
            .agg(ocr_text_sum=('ocr_text', lambda x: ' | '.join([str(i) for i in x if i])))
        )
        
        # 6. URL 매핑 추가 (파일이 있을 경우)
        logger.info("===== 6단계: URL 매핑 추가 =====")
        url_mapping_path = base_path.parent / "IBK_문서" / "url_index_mapping.csv"
        if url_mapping_path.exists():
            try:
                df_url_index = pd.read_csv(url_mapping_path)
                logger.info(f"URL 매핑 로드 성공: {len(df_url_index)}개 항목")
                # 여기서 매핑 처리 로직을 추가할 수 있음
            except Exception as e:
                logger.warning(f"URL 매핑 로드 실패: {e}")
        else:
            logger.warning(f"URL 매핑 파일 없음: {url_mapping_path}")
        
        # 7. text.txt 파일 내용 추가
        logger.info("===== 7단계: 텍스트 파일 내용 추가 =====")
        final_df = process_text_files(grouped_df, base_path)
        
        # 8. 최종 결과 저장
        logger.info("===== 8단계: 최종 결과 저장 =====")
        final_parquet_path = base_path / f"{output_base_name}_final.parquet"
        save_to_parquet_safely(final_df, final_parquet_path)
        
        logger.info("===== 전체 워크플로우 완료 =====")
        return final_df
    
    except Exception as e:
        logger.error(f"워크플로우 실행 중 심각한 오류 발생: {e}")
        import traceback
        logger.error(traceback.format_exc())  # 상세 오류 스택 출력
        return pd.DataFrame()  # 오류 발생해도 빈 데이터프레임 반환

# %% [markdown]
# 7. 실행 코드

# %%
# 전체 파이프라인 실행
result_df = run_full_workflow(BASE_PATH, "IBK_24801_32081_add_text_plus")

# 결과 확인
if result_df is not None:
    display(result_df.head())
    print(f"총 {len(result_df)}개 항목 처리됨")
    
    # 데이터 품질 체크
    print("\n== 데이터 결측치 현황 ==")
    display(result_df.isnull().sum())
    
    # 요약 통계
    print("\n== 텍스트 길이 통계 ==")
    result_df['ocr_text_length'] = result_df['ocr_text_sum'].str.len()
    result_df['text_length'] = result_df['text'].str.len()
    display(result_df[['ocr_text_length', 'text_length']].describe())
# Out:
# 2025-05-14 13:24:54,760 - INFO - ===== 1단계: CSV 데이터 수집 =====
# 폴더 스캔 중:   0%|          | 0/59600 [00:00<?, ?it/s]
# 2025-05-14 13:25:01,352 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_준법감시_유효기간_20250514_131538.csv (420 행)
# 2025-05-14 13:25:01,402 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24801\ocr_results.csv (5 행)
# 2025-05-14 13:25:01,415 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24802\ocr_results.csv (16 행)
# 2025-05-14 13:25:01,427 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24803\ocr_results.csv (16 행)
# 2025-05-14 13:25:01,439 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24804\ocr_results.csv (16 행)
# 2025-05-14 13:25:01,452 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24805\ocr_results.csv (9 행)
# 2025-05-14 13:25:01,465 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24806\ocr_results.csv (14 행)
# 2025-05-14 13:25:01,476 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24807\ocr_results.csv (7 행)
# 2025-05-14 13:25:01,488 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24808\ocr_results.csv (16 행)
# 2025-05-14 13:25:01,501 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24809\ocr_results.csv (9 행)
# 2025-05-14 13:25:01,513 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24810\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,523 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24811\ocr_results.csv (6 행)
# 2025-05-14 13:25:01,536 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24812\ocr_results.csv (6 행)
# 2025-05-14 13:25:01,547 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24813\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,558 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24814\ocr_results.csv (14 행)
# 2025-05-14 13:25:01,570 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24816\ocr_results.csv (6 행)
# 2025-05-14 13:25:01,582 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24817\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,593 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24818\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,605 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24819\ocr_results.csv (31 행)
# 2025-05-14 13:25:01,617 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24820\ocr_results.csv (2 행)
# 2025-05-14 13:25:01,629 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24821\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,639 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24822\ocr_results.csv (12 행)
# 2025-05-14 13:25:01,652 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24823\ocr_results.csv (14 행)
# 2025-05-14 13:25:01,665 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24824\ocr_results.csv (13 행)
# 2025-05-14 13:25:01,676 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24825\ocr_results.csv (12 행)
# 2025-05-14 13:25:01,687 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24826\ocr_results.csv (1 행)
# 2025-05-14 13:25:01,699 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24827\ocr_results.csv (7 행)
# 2025-05-14 13:25:01,710 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24828\ocr_results.csv (15 행)
# 2025-05-14 13:25:01,722 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24829\ocr_results.csv (1 행)
# 2025-05-14 13:25:01,737 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24831\ocr_results.csv (7 행)
# 2025-05-14 13:25:01,749 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24832\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,759 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24833\ocr_results.csv (4 행)
# 2025-05-14 13:25:01,771 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24834\ocr_results.csv (5 행)
# 2025-05-14 13:25:01,783 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24835\ocr_results.csv (13 행)
# 2025-05-14 13:25:01,794 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24836\ocr_results.csv (12 행)
# 2025-05-14 13:25:01,805 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24837\ocr_results.csv (1 행)
# 2025-05-14 13:25:01,816 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24838\ocr_results.csv (1 행)
# 2025-05-14 13:25:01,828 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24839\ocr_results.csv (19 행)
# 2025-05-14 13:25:01,840 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24840\ocr_results.csv (12 행)
# 2025-05-14 13:25:01,852 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24841\ocr_results.csv (38 행)
# 2025-05-14 13:25:01,865 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24842\ocr_results.csv (11 행)
# 2025-05-14 13:25:01,877 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24843\ocr_results.csv (22 행)
# 2025-05-14 13:25:01,892 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24844\ocr_results.csv (14 행)
# 2025-05-14 13:25:01,906 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24845\ocr_results.csv (4 행)
# 2025-05-14 13:25:01,919 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24846\ocr_results.csv (3 행)
# 2025-05-14 13:25:01,935 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24847\ocr_results.csv (7 행)
# 2025-05-14 13:25:01,947 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24849\ocr_results.csv (1 행)
# 2025-05-14 13:25:01,958 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24850\ocr_results.csv (11 행)
# 2025-05-14 13:25:01,970 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24851\ocr_results.csv (17 행)
# 2025-05-14 13:25:01,982 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24852\ocr_results.csv (12 행)
# 2025-05-14 13:25:01,993 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24853\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,004 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24854\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,016 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24855\ocr_results.csv (16 행)
# 2025-05-14 13:25:02,027 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24856\ocr_results.csv (5 행)
# 2025-05-14 13:25:02,038 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24858\ocr_results.csv (4 행)
# 2025-05-14 13:25:02,049 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24859\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,060 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24860\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,071 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24861\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,083 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24862\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,094 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24863\ocr_results.csv (14 행)
# 2025-05-14 13:25:02,104 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24864\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,116 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24865\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,127 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24866\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,139 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24868\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,152 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24869\ocr_results.csv (20 행)
# 2025-05-14 13:25:02,163 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24870\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,173 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24871\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,185 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24872\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,195 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24873\ocr_results.csv (4 행)
# 2025-05-14 13:25:02,206 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24874\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,218 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24875\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,231 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24878\ocr_results.csv (18 행)
# 2025-05-14 13:25:02,242 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24879\ocr_results.csv (18 행)
# 2025-05-14 13:25:02,253 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24880\ocr_results.csv (17 행)
# 2025-05-14 13:25:02,265 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24881\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,278 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24882\ocr_results.csv (45 행)
# 2025-05-14 13:25:02,288 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24883\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,300 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24885\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,313 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24886\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,327 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24887\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,340 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24888\ocr_results.csv (21 행)
# 2025-05-14 13:25:02,353 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24889\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,365 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24891\ocr_results.csv (8 행)
# 2025-05-14 13:25:02,376 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24892\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,387 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24893\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,398 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24894\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,412 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24895\ocr_results.csv (19 행)
# 2025-05-14 13:25:02,423 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24896\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,435 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24899\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,448 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24901\ocr_results.csv (15 행)
# 2025-05-14 13:25:02,459 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24903\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,470 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24904\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,482 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24905\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,494 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24906\ocr_results.csv (16 행)
# 2025-05-14 13:25:02,506 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24907\ocr_results.csv (17 행)
# 2025-05-14 13:25:02,518 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24908\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,532 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24909\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,545 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24910\ocr_results.csv (14 행)
# 2025-05-14 13:25:02,557 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24911\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,570 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24912\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,581 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24914\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,592 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24915\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,607 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24921\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,618 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24922\ocr_results.csv (5 행)
# 2025-05-14 13:25:02,629 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24923\ocr_results.csv (8 행)
# 2025-05-14 13:25:02,643 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24924\ocr_results.csv (43 행)
# 2025-05-14 13:25:02,656 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24925\ocr_results.csv (29 행)
# 2025-05-14 13:25:02,670 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24927\ocr_results.csv (43 행)
# 2025-05-14 13:25:02,681 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24929\ocr_results.csv (7 행)
# 2025-05-14 13:25:02,694 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24932\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,706 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24933\ocr_results.csv (9 행)
# 2025-05-14 13:25:02,718 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24934\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,731 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24935\ocr_results.csv (24 행)
# 2025-05-14 13:25:02,742 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24937\ocr_results.csv (4 행)
# 2025-05-14 13:25:02,754 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24938\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,766 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24939\ocr_results.csv (4 행)
# 2025-05-14 13:25:02,777 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24940\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,788 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24941\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,799 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24942\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,811 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24944\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,822 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24945\ocr_results.csv (2 행)
# 2025-05-14 13:25:02,836 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24946\ocr_results.csv (22 행)
# 2025-05-14 13:25:02,848 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24948\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,862 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24949\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,877 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24950\ocr_results.csv (3 행)
# 2025-05-14 13:25:02,895 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24951\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,909 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24952\ocr_results.csv (14 행)
# 2025-05-14 13:25:02,922 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24953\ocr_results.csv (10 행)
# 2025-05-14 13:25:02,933 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24954\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,946 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24957\ocr_results.csv (11 행)
# 2025-05-14 13:25:02,960 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24960\ocr_results.csv (1 행)
# 2025-05-14 13:25:02,971 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24961\ocr_results.csv (11 행)
# 2025-05-14 13:25:02,982 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24962\ocr_results.csv (6 행)
# 2025-05-14 13:25:02,993 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24963\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,004 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24964\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,015 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24965\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,028 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24966\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,039 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24968\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,051 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24969\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,061 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24970\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,072 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24971\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,084 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24972\ocr_results.csv (11 행)
# 2025-05-14 13:25:03,095 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24973\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,107 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24974\ocr_results.csv (6 행)
# 2025-05-14 13:25:03,119 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24975\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,131 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24976\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,142 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24977\ocr_results.csv (9 행)
# 2025-05-14 13:25:03,154 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24978\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,166 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24979\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,177 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24980\ocr_results.csv (4 행)
# 2025-05-14 13:25:03,190 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24985\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,202 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24986\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,214 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24987\ocr_results.csv (17 행)
# 2025-05-14 13:25:03,225 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24989\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,238 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24993\ocr_results.csv (4 행)
# 2025-05-14 13:25:03,249 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24994\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,262 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24996\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,273 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\24998\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,285 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25000\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,296 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25001\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,308 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25004\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,320 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25005\ocr_results.csv (20 행)
# 2025-05-14 13:25:03,332 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25007\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,343 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25008\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,354 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25010\ocr_results.csv (6 행)
# 2025-05-14 13:25:03,367 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25011\ocr_results.csv (10 행)
# 2025-05-14 13:25:03,379 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25013\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,390 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25014\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,402 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25015\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,413 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25016\ocr_results.csv (7 행)
# 2025-05-14 13:25:03,424 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25017\ocr_results.csv (4 행)
# 2025-05-14 13:25:03,437 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25018\ocr_results.csv (19 행)
# 2025-05-14 13:25:03,448 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25019\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,459 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25020\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,471 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25021\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,484 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25022\ocr_results.csv (12 행)
# 2025-05-14 13:25:03,495 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25023\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,506 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25024\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,519 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25025\ocr_results.csv (27 행)
# 2025-05-14 13:25:03,530 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25026\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,540 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25027\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,552 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25029\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,563 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25030\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,575 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25032\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,587 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25033\ocr_results.csv (13 행)
# 2025-05-14 13:25:03,598 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25034\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,609 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25035\ocr_results.csv (4 행)
# 2025-05-14 13:25:03,622 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25036\ocr_results.csv (19 행)
# 2025-05-14 13:25:03,634 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25037\ocr_results.csv (4 행)
# 2025-05-14 13:25:03,645 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25039\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,657 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25041\ocr_results.csv (14 행)
# 2025-05-14 13:25:03,671 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25042\ocr_results.csv (22 행)
# 2025-05-14 13:25:03,683 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25043\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,694 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25044\ocr_results.csv (11 행)
# 2025-05-14 13:25:03,706 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25046\ocr_results.csv (17 행)
# 2025-05-14 13:25:03,719 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25048\ocr_results.csv (17 행)
# 2025-05-14 13:25:03,731 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25049\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,741 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25050\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,753 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25051\ocr_results.csv (9 행)
# 2025-05-14 13:25:03,765 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25053\ocr_results.csv (3 행)
# 2025-05-14 13:25:03,776 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25054\ocr_results.csv (16 행)
# 2025-05-14 13:25:03,787 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25055\ocr_results.csv (8 행)
# 2025-05-14 13:25:03,799 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25057\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,811 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25058\ocr_results.csv (35 행)
# 2025-05-14 13:25:03,823 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25059\ocr_results.csv (9 행)
# 2025-05-14 13:25:03,835 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25060\ocr_results.csv (13 행)
# 2025-05-14 13:25:03,850 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25061\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,865 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25062\ocr_results.csv (2 행)
# 2025-05-14 13:25:03,880 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25063\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,893 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25065\ocr_results.csv (17 행)
# 2025-05-14 13:25:03,904 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25066\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,915 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25067\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,927 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25068\ocr_results.csv (5 행)
# 2025-05-14 13:25:03,939 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25070\ocr_results.csv (6 행)
# 2025-05-14 13:25:03,951 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25071\ocr_results.csv (10 행)
# 2025-05-14 13:25:03,961 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25072\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,973 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25073\ocr_results.csv (16 행)
# 2025-05-14 13:25:03,986 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25076\ocr_results.csv (1 행)
# 2025-05-14 13:25:03,998 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25078\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,008 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25079\ocr_results.csv (4 행)
# 2025-05-14 13:25:04,019 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25080\ocr_results.csv (14 행)
# 2025-05-14 13:25:04,031 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25081\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,045 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25084\ocr_results.csv (35 행)
# 2025-05-14 13:25:04,056 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25085\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,068 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25087\ocr_results.csv (11 행)
# 2025-05-14 13:25:04,080 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25089\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,092 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25090\ocr_results.csv (15 행)
# 2025-05-14 13:25:04,104 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25091\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,116 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25092\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,127 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25093\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,138 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25095\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,150 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25096\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,162 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25098\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,174 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25100\ocr_results.csv (4 행)
# 2025-05-14 13:25:04,186 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25101\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,196 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25102\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,207 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25103\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,218 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25104\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,230 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25105\ocr_results.csv (7 행)
# 2025-05-14 13:25:04,243 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25107\ocr_results.csv (22 행)
# 2025-05-14 13:25:04,255 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25109\ocr_results.csv (17 행)
# 2025-05-14 13:25:04,267 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25110\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,278 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25111\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,289 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25112\ocr_results.csv (15 행)
# 2025-05-14 13:25:04,302 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25114\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,313 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25115\ocr_results.csv (9 행)
# 2025-05-14 13:25:04,325 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25117\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,335 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25118\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,348 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25120\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,359 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25122\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,371 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25123\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,382 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25124\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,393 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25125\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,405 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25127\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,417 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25128\ocr_results.csv (12 행)
# 2025-05-14 13:25:04,429 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25129\ocr_results.csv (11 행)
# 2025-05-14 13:25:04,440 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25130\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,453 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25131\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,467 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25132\ocr_results.csv (32 행)
# 2025-05-14 13:25:04,480 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25133\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,490 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25134\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,502 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25135\ocr_results.csv (7 행)
# 2025-05-14 13:25:04,512 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25136\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,523 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25137\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,535 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25138\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,546 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25139\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,556 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25140\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,568 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25141\ocr_results.csv (4 행)
# 2025-05-14 13:25:04,578 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25142\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,589 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25143\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,600 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25144\ocr_results.csv (7 행)
# 2025-05-14 13:25:04,612 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25145\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,621 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25146\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,632 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25147\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,641 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25148\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,653 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25149\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,667 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25150\ocr_results.csv (9 행)
# 2025-05-14 13:25:04,679 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25151\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,692 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25152\ocr_results.csv (14 행)
# 2025-05-14 13:25:04,704 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25153\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,716 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25154\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,730 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25156\ocr_results.csv (15 행)
# 2025-05-14 13:25:04,741 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25157\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,756 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25159\ocr_results.csv (25 행)
# 2025-05-14 13:25:04,773 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25160\ocr_results.csv (13 행)
# 2025-05-14 13:25:04,787 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25161\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,801 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25162\ocr_results.csv (10 행)
# 2025-05-14 13:25:04,815 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25166\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,826 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25167\ocr_results.csv (3 행)
# 2025-05-14 13:25:04,837 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25168\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,848 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25169\ocr_results.csv (2 행)
# 2025-05-14 13:25:04,861 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25170\ocr_results.csv (13 행)
# 2025-05-14 13:25:04,872 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25172\ocr_results.csv (8 행)
# 2025-05-14 13:25:04,885 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25173\ocr_results.csv (5 행)
# 2025-05-14 13:25:04,896 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25174\ocr_results.csv (4 행)
# 2025-05-14 13:25:04,906 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25175\ocr_results.csv (6 행)
# 2025-05-14 13:25:04,918 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25176\ocr_results.csv (14 행)
# 2025-05-14 13:25:04,930 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25177\ocr_results.csv (9 행)
# 2025-05-14 13:25:04,941 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25178\ocr_results.csv (7 행)
# 2025-05-14 13:25:04,952 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25179\ocr_results.csv (1 행)
# 2025-05-14 13:25:04,963 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25180\ocr_results.csv (8 행)
# 2025-05-14 13:25:04,977 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25181\ocr_results.csv (27 행)
# 2025-05-14 13:25:04,988 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25183\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,001 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25184\ocr_results.csv (20 행)
# 2025-05-14 13:25:05,015 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25185\ocr_results.csv (49 행)
# 2025-05-14 13:25:05,027 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25186\ocr_results.csv (40 행)
# 2025-05-14 13:25:05,038 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25187\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,050 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25189\ocr_results.csv (9 행)
# 2025-05-14 13:25:05,062 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25190\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,072 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25191\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,086 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25194\ocr_results.csv (9 행)
# 2025-05-14 13:25:05,100 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25195\ocr_results.csv (58 행)
# 2025-05-14 13:25:05,112 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25197\ocr_results.csv (13 행)
# 2025-05-14 13:25:05,123 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25200\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,134 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25201\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,146 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25202\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,158 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25204\ocr_results.csv (7 행)
# 2025-05-14 13:25:05,169 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25205\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,180 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25206\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,191 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25207\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,202 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25208\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,213 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25209\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,224 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25210\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,235 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25211\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,249 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25212\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,261 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25213\ocr_results.csv (11 행)
# 2025-05-14 13:25:05,273 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25217\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,284 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25218\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,297 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25220\ocr_results.csv (6 행)
# 2025-05-14 13:25:05,307 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25221\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,318 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25222\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,329 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25223\ocr_results.csv (3 행)
# 2025-05-14 13:25:05,340 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25224\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,351 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25225\ocr_results.csv (3 행)
# 2025-05-14 13:25:05,362 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25226\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,375 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25228\ocr_results.csv (13 행)
# 2025-05-14 13:25:05,387 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25230\ocr_results.csv (4 행)
# 2025-05-14 13:25:05,398 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25231\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,408 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25232\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,421 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25234\ocr_results.csv (6 행)
# 2025-05-14 13:25:05,432 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25235\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,444 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25237\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,455 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25239\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,466 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25240\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,478 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25241\ocr_results.csv (3 행)
# 2025-05-14 13:25:05,489 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25242\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,501 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25244\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,514 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25248\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,524 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25250\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,536 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25251\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,548 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25253\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,566 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25255\ocr_results.csv (29 행)
# 2025-05-14 13:25:05,581 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25257\ocr_results.csv (13 행)
# 2025-05-14 13:25:05,598 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25259\ocr_results.csv (37 행)
# 2025-05-14 13:25:05,611 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25260\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,622 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25261\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,633 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25262\ocr_results.csv (3 행)
# 2025-05-14 13:25:05,646 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25265\ocr_results.csv (10 행)
# 2025-05-14 13:25:05,657 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25266\ocr_results.csv (15 행)
# 2025-05-14 13:25:05,669 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25268\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,680 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25271\ocr_results.csv (5 행)
# 2025-05-14 13:25:05,693 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25273\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,706 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25276\ocr_results.csv (3 행)
# 2025-05-14 13:25:05,718 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25277\ocr_results.csv (16 행)
# 2025-05-14 13:25:05,732 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25278\ocr_results.csv (20 행)
# 2025-05-14 13:25:05,743 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25279\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,756 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25283\ocr_results.csv (6 행)
# 2025-05-14 13:25:05,769 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25288\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,780 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25289\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,791 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25290\ocr_results.csv (2 행)
# 2025-05-14 13:25:05,802 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25291\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,813 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25292\ocr_results.csv (1 행)
# 2025-05-14 13:25:05,824 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\ibk_24801_start_2\25293\ocr_results.csv (1 행)
# ...
# 2025-05-14 13:28:13,570 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36662\ocr_results.csv
# 2025-05-14 13:28:13,571 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36663\ocr_results.csv
# 2025-05-14 13:28:13,573 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36664\ocr_results.csv
# 2025-05-14 13:28:13,576 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36665\ocr_results.csv
# 2025-05-14 13:28:13,577 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36666\ocr_results.csv
# 2025-05-14 13:28:13,579 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36667\ocr_results.csv
# 2025-05-14 13:28:13,580 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36668\ocr_results.csv
# 2025-05-14 13:28:13,582 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36669\ocr_results.csv
# 2025-05-14 13:28:13,585 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36671\ocr_results.csv
# 2025-05-14 13:28:13,586 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36672\ocr_results.csv
# 2025-05-14 13:28:13,588 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36674\ocr_results.csv
# 2025-05-14 13:28:13,590 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36675\ocr_results.csv
# 2025-05-14 13:28:13,592 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36676\ocr_results.csv
# 2025-05-14 13:28:13,593 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36677\ocr_results.csv
# 2025-05-14 13:28:13,595 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36678\ocr_results.csv
# 2025-05-14 13:28:13,596 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36679\ocr_results.csv
# 2025-05-14 13:28:13,598 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36680\ocr_results.csv
# 2025-05-14 13:28:13,599 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36682\ocr_results.csv
# 2025-05-14 13:28:13,601 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36683\ocr_results.csv
# 2025-05-14 13:28:13,602 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36684\ocr_results.csv
# 2025-05-14 13:28:13,603 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36685\ocr_results.csv
# 2025-05-14 13:28:13,607 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36687\ocr_results.csv
# 2025-05-14 13:28:13,609 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36688\ocr_results.csv
# 2025-05-14 13:28:13,610 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36689\ocr_results.csv
# 2025-05-14 13:28:13,612 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36690\ocr_results.csv
# 2025-05-14 13:28:13,613 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36691\ocr_results.csv
# 2025-05-14 13:28:13,616 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36693\ocr_results.csv
# 2025-05-14 13:28:13,617 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36694\ocr_results.csv
# 2025-05-14 13:28:13,619 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36695\ocr_results.csv
# 2025-05-14 13:28:13,621 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36696\ocr_results.csv
# 2025-05-14 13:28:13,623 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36697\ocr_results.csv
# 2025-05-14 13:28:13,626 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36699\ocr_results.csv
# 2025-05-14 13:28:13,628 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36700\ocr_results.csv
# 2025-05-14 13:28:13,630 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36701\ocr_results.csv
# 2025-05-14 13:28:13,631 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36702\ocr_results.csv
# 2025-05-14 13:28:13,633 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36703\ocr_results.csv
# 2025-05-14 13:28:13,637 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36705\ocr_results.csv
# 2025-05-14 13:28:13,639 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36706\ocr_results.csv
# 2025-05-14 13:28:13,641 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36707\ocr_results.csv
# 2025-05-14 13:28:13,643 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36708\ocr_results.csv
# 2025-05-14 13:28:13,645 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36709\ocr_results.csv
# 2025-05-14 13:28:13,646 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36710\ocr_results.csv
# 2025-05-14 13:28:13,650 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36712\ocr_results.csv
# 2025-05-14 13:28:13,651 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36713\ocr_results.csv
# 2025-05-14 13:28:13,653 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36715\ocr_results.csv
# 2025-05-14 13:28:13,654 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36716\ocr_results.csv
# 2025-05-14 13:28:13,655 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36717\ocr_results.csv
# 2025-05-14 13:28:13,657 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36719\ocr_results.csv
# 2025-05-14 13:28:13,658 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36720\ocr_results.csv
# 2025-05-14 13:28:13,659 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36721\ocr_results.csv
# 2025-05-14 13:28:13,661 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36722\ocr_results.csv
# 2025-05-14 13:28:13,663 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36723\ocr_results.csv
# 2025-05-14 13:28:13,665 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36724\ocr_results.csv
# 2025-05-14 13:28:13,668 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36725\ocr_results.csv
# 2025-05-14 13:28:13,670 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36726\ocr_results.csv
# 2025-05-14 13:28:13,672 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36727\ocr_results.csv
# 2025-05-14 13:28:13,674 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36728\ocr_results.csv
# 2025-05-14 13:28:13,676 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36729\ocr_results.csv
# 2025-05-14 13:28:13,678 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36730\ocr_results.csv
# 2025-05-14 13:28:13,679 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36731\ocr_results.csv
# 2025-05-14 13:28:13,681 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36732\ocr_results.csv
# 2025-05-14 13:28:13,683 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36734\ocr_results.csv
# 2025-05-14 13:28:13,685 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36735\ocr_results.csv
# 2025-05-14 13:28:13,686 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36736\ocr_results.csv
# 2025-05-14 13:28:13,688 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36738\ocr_results.csv
# 2025-05-14 13:28:13,689 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36739\ocr_results.csv
# 2025-05-14 13:28:13,690 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36740\ocr_results.csv
# 2025-05-14 13:28:13,691 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36741\ocr_results.csv
# 2025-05-14 13:28:13,694 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36743\ocr_results.csv
# 2025-05-14 13:28:13,696 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36744\ocr_results.csv
# 2025-05-14 13:28:13,698 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36745\ocr_results.csv
# 2025-05-14 13:28:13,701 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36747\ocr_results.csv
# 2025-05-14 13:28:13,703 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36749\ocr_results.csv
# 2025-05-14 13:28:13,706 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36750\ocr_results.csv
# 2025-05-14 13:28:13,708 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36751\ocr_results.csv
# 2025-05-14 13:28:13,710 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36752\ocr_results.csv
# 2025-05-14 13:28:13,714 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36756\ocr_results.csv
# 2025-05-14 13:28:13,718 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36760\ocr_results.csv
# 2025-05-14 13:28:13,720 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36762\ocr_results.csv
# 2025-05-14 13:28:13,721 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36763\ocr_results.csv
# 2025-05-14 13:28:13,724 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36765\ocr_results.csv
# 2025-05-14 13:28:13,725 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36766\ocr_results.csv
# 2025-05-14 13:28:13,727 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36768\ocr_results.csv
# 2025-05-14 13:28:13,729 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36769\ocr_results.csv
# 2025-05-14 13:28:13,731 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36770\ocr_results.csv
# 2025-05-14 13:28:13,733 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36771\ocr_results.csv
# 2025-05-14 13:28:13,735 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36772\ocr_results.csv
# 2025-05-14 13:28:13,737 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36774\ocr_results.csv
# 2025-05-14 13:28:13,739 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36775\ocr_results.csv
# 2025-05-14 13:28:13,740 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36776\ocr_results.csv
# 2025-05-14 13:28:13,741 - WARNING - 빈 CSV 파일: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start\36777\ocr_results.csv
# 2025-05-14 13:28:14,678 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start_2_미사용파일\all_ocr_results.csv (34502 행)
# 2025-05-14 13:28:14,714 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\ibk_32081_start_미사용파일\all_ocr_results.csv (34502 행)
# 2025-05-14 13:28:14,809 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_문서\새 폴더\IBK_ALL_add_text_remove_nan.csv (19559 행)
# 2025-05-14 13:28:14,839 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\IBK_24801_32081_add_text_url_통과.csv (67 행)
# 2025-05-14 13:28:14,863 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_csv화_불필요드랍.csv (5877 행)
# 2025-05-14 13:28:14,897 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터1_2차_통과_추가필터용.csv (5877 행)
# 2025-05-14 13:28:15,796 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터_1_1차_실패.csv (15090 행)
# 2025-05-14 13:28:15,825 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터_1_1차_통과.csv (17 행)
# 2025-05-14 13:28:15,840 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터_1_1차_통과_위반유무.csv (17 행)
# 2025-05-14 13:28:15,976 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터_1_2차_1개이상_통과.csv (1451 행)
# 2025-05-14 13:28:16,013 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\필터_검증_1_3차_통과.csv (160 행)
# 2025-05-14 13:28:16,040 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\10월.csv (1201 행)
# 2025-05-14 13:28:16,066 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\11월.csv (1252 행)
# 2025-05-14 13:28:16,088 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\12월.csv (561 행)
# 2025-05-14 13:28:16,111 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\251월.csv (452 행)
# 2025-05-14 13:28:16,126 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\7월.csv (246 행)
# 2025-05-14 13:28:16,153 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\8월.csv (1046 행)
# 2025-05-14 13:28:16,175 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\9월.csv (1119 행)
# 2025-05-14 13:28:16,206 - INFO - CSV 파일 읽기 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_작업\최종_데이터_관련\최종_데이터_csv화.csv (5877 행)
# 2025-05-14 13:28:35,240 - INFO - 총 442517개 행 수집 완료
# 2025-05-14 13:28:35,318 - INFO - ===== 2단계: OCR 텍스트 추가 =====
# 2025-05-14 13:28:35,502 - INFO - OCR 텍스트 442517개 로딩 중...
# OCR 텍스트 읽기:   0%|          | 0/442517 [00:00<?, ?it/s]
# 2025-05-14 13:28:57,557 - INFO - ===== 3단계: 첫 번째 Parquet 저장 =====
# 2025-05-14 13:29:00,582 - INFO - Parquet 저장 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_24801_32081_add_text_plus_step1.parquet (442517 행)
# 2025-05-14 13:29:00,582 - INFO - ===== 4단계: 데이터 필터링 =====
# 2025-05-14 13:29:00,592 - INFO - ===== 5단계: 폴더별 텍스트 통합 =====
# 2025-05-14 13:29:00,903 - INFO - ===== 6단계: URL 매핑 추가 =====
# 2025-05-14 13:29:00,904 - WARNING - URL 매핑 파일 없음: C:\Users\markcloud\Desktop\오준호\IBK_문서\url_index_mapping.csv
# 2025-05-14 13:29:00,904 - INFO - ===== 7단계: 텍스트 파일 내용 추가 =====
# 텍스트 파일 처리:   0%|          | 0/15111 [00:00<?, ?it/s]
# 2025-05-14 13:30:26,779 - WARNING - [스킵] 번호 범위 밖: IBK
# 2025-05-14 13:30:26,779 - WARNING - [스킵] 번호 범위 밖: IBK_문서
# 2025-05-14 13:30:26,780 - WARNING - [스킵] 번호 범위 밖: IBK_작업
# 2025-05-14 13:30:26,781 - WARNING - [스킵] 번호 범위 밖: 최종_데이터_관련
# 2025-05-14 13:30:26,785 - INFO - ===== 8단계: 최종 결과 저장 =====
# 2025-05-14 13:30:27,236 - INFO - Parquet 저장 성공: C:\Users\markcloud\Desktop\오준호\IBK\IBK_24801_32081_add_text_plus_final.parquet (15111 행)
# 2025-05-14 13:30:27,236 - INFO - ===== 전체 워크플로우 완료 =====
#   folder ocr_text_sum                                               text
# 0  24801               오창 24시 해장국\n" 노걸대 감자탕 "\n오창점\n「 글 · 사진 」\n유감독\...
# 1  24802               엄지척 절로 나오는 여수 이순신광장 빵집\n갓버터도나스\n\n올해로 벌써 여수 여행...
# 2  24803               안녕하세요\n포로롱 입니다\n\n오늘은\n대구 교동에 레트로감성이 물씬 느껴지는\n...
# 3  24804               [대구 중구] 교동뭉티기\n📍주소: 대구 중구 국채보상로123길 15 102호\n🕰...
# 4  24805               남편은 일산에서 꽤 오래 살았다.\n하지만 인천에 오래 살아도 타 지역 사람보다 맛...
# 총 15111개 항목 처리됨
#
# == 데이터 결측치 현황 ==
# folder          0
# ocr_text_sum    0
# text            0
# dtype: int64
# == 텍스트 길이 통계 ==
#        ocr_text_length   text_length
# count          15111.0  15111.000000
# mean               0.0   2202.839389
# std                0.0   2838.972034
# min                0.0      0.000000
# 25%                0.0   1058.000000
# 50%                0.0   1636.000000
# 75%                0.0   2424.500000
# max                0.0  76100.000000
